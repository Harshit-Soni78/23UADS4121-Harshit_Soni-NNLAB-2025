# %% [markdown]
# # This is to visualise the trial dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # type: ignore

# %%
hs_EEC1 = pd.read_csv('hs_EE-C1.csv')
hs_EEC2 = pd.read_csv('hs_EE-C2.csv')
hs_EEG1 = pd.read_csv('hs_EE-G1.csv')
hs_EEG2 = pd.read_csv('hs_EE-G1.csv')

# %%
hs_EEC1.head()
# Out:
#   ID    SrNo      Timestamp    X_Acc    Y_Acc     Z_Acc    X_Gyro    Y_Gyro  \
# 0  hs      1  1738146201877  1.12695 -3.00495  11.58195  -1.77259  -6.34193
# 1  hs      2  1738146201898  1.03095 -5.83305  11.92005  -5.97165   8.35874
# 2  hs      3  1738146201903 -0.85005  3.18300   8.66100  11.66757 -11.87240
# 3  hs      4  1738146201916 -0.85005  3.18300   8.66100   6.27890   4.08877
# 4  hs      5  1738146201922  0.04905 -4.46295  14.00505  -8.49267   6.75159
#
#     Z_Gyro
# 0  -5.81409
# 1  -0.35452
# 2  -2.31618
# 3  -0.07090
# 4   2.02469

# %%
# pd.to_datetime(hs_EEC1.columns[1:], format='%Y-%m-%d')
hs_EEC1.columns[2]
# Out:
# Index(['ID ', ' SrNo'], dtype='object')

# %%
sns.pairplot(hs_EEC1)
sns.pairplot(hs_EEC2)
sns.pairplot(hs_EEG1)
sns.pairplot(hs_EEG2)
