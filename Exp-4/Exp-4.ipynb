# %% [markdown]
# 4. WAP to evaluate the performance of implemented three-layer neural network with variations in activation functions, size of hidden layer, learning rate, batch size and number of epochs.

# %% [markdown]
# - 4121 % 3 = 2
#
# | Activation   | Layers   | Learning Rate  | Batch Size  | No. of Epochs | Execution time  |
# | ------------ | -------- | -------------- | ----------- | ------------- | --------------- |
# | {Activation} | {Layers} | {LearningRate} | {BatchSize} | {Epochs}      | {ExecutionTime} |

# %% [markdown]
# Modify the given code so that I can

# %% [markdown]
# hay gpt, in the next experiment, write a python code to evaluate the performance of implemented three-layer neural network with variations in activation functions, size of hidden layer, learning rate, batch size and number of epochs.
#
# I want to change the existing code of previous experiment to do this,
#
# # Variations to test
# activations = ['relu', 'tanh', 'sigmoid']
#
# hidden_layer_sizes_single_layer = [256, 128, 64]
# hidden_layer_sizes_double_layer = [(160,100), (100,160), (100,100), (100,60), (60,60)]
#
# # hidden_layer_sizes = hidden_layer_sizes_single_layer + hidden_layer_sizes_double_layer
#
# learning_rates = [0.1 , 0.01, 0.001]
# batch_sizes = [100, 10, 1]
# epochs_list = [100, 50, 10]
#
#
# I also want answer to be shown in a tabular form,
#
# table structure,
# Srno. | Activation func | No of Layer | Learning rate | Batch size | No. of epoch | loss curve | accuracy curve | test accuracy | confusion matrix | execution time |
#
# I want this table for single layer and double layer seperatly.
#
# I am using ipynb file to do this experiment.

# %%
print(4121%3)
# Out:
# 2

# %%
# Variations to test
activations = ['relu', 'tanh', 'sigmoid']

hidden_layer_sizes_single_layer = [256, 128, 64]
hidden_layer_sizes_double_layer = [(160,100), (100,160), (100,100), (100,60), (60,60)]

# hidden_layer_sizes = hidden_layer_sizes_single_layer + hidden_layer_sizes_double_layer

learning_rates = [0.1 , 0.01, 0.001]
batch_sizes = [100, 10, 1]
epochs_list = [100, 50, 10]

table = [['Activation', 'Layers', 'Learning Rate', 'Batch Size', 'No. of Epochs', 'Execution time']]

# Running experiments
for activation in activations:
    for layers in hidden_layer_sizes:
        for learning_rate in learning_rates:
            for batch_size in batch_sizes:
                for epochs in epochs_list:
                    row = [activation, layers, learning_rate, batch_size, epochs]
                    table.append(row)
                    
#                     print(f'''
# | Activation   | Layers   | Learning Rate  | Batch Size  | No. of Epochs | Execution time  |
# | ------------ | -------- | -------------- | ----------- | ------------- | --------------- |
# | {activation} | {layer} | {learning_rate} | {batch_size} | {epochs}      | ExecutionTime |
# ''')

# %%
import time

# Variations to test
activations = ['relu', 'tanh', 'sigmoid']
hidden_layer_sizes = [[256], [128], [64], [160, 100], [100, 160], [100, 100], [100, 60], [60, 60]]
learning_rates = [0.1, 0.01, 0.001]
batch_sizes = [100, 10, 1]
epochs_list = [100, 50, 10]

table = [['Activation', 'Layers', 'Learning Rate', 'Batch Size', 'No. of Epochs', 'Execution time']]

# Running experiments
for activation in activations:
    for layers in hidden_layer_sizes:
        for learning_rate in learning_rates:
            for batch_size in batch_sizes:
                for epochs in epochs_list:
                    start_time = time.time()
                    
                    # Your code to run the experiment goes here
                    # For example:
                    # model = create_model(activation, layers, learning_rate)
                    # train_model(model, batch_size, epochs)
                    
                    end_time = time.time()
                    execution_time = end_time - start_time
                    row = [activation, layers, learning_rate, batch_size, epochs, execution_time]
                    table.append(row)

# Print the table

from tabulate import tabulate
print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒══════════════╤════════════╤═════════════════╤══════════════╤═════════════════╤══════════════════╕
# │ Activation   │ Layers     │   Learning Rate │   Batch Size │   No. of Epochs │   Execution time │
# ╞══════════════╪════════════╪═════════════════╪══════════════╪═════════════════╪══════════════════╡
# │ relu         │ [256]      │           0.1   │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.1   │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.1   │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.1   │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.1   │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.1   │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.1   │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.1   │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.1   │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.01  │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.01  │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.01  │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.01  │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.01  │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.01  │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.01  │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.01  │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.01  │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.001 │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.001 │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.001 │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.001 │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.001 │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.001 │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.001 │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.001 │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [256]      │           0.001 │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.1   │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.1   │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.1   │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.1   │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.1   │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.1   │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.1   │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.1   │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.1   │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.01  │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.01  │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.01  │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.01  │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.01  │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.01  │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.01  │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.01  │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.01  │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.001 │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.001 │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.001 │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.001 │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.001 │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.001 │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.001 │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.001 │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [128]      │           0.001 │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.1   │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.1   │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.1   │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.1   │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.1   │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.1   │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.1   │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.1   │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.1   │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.01  │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.01  │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.01  │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.01  │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.01  │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.01  │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.01  │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.01  │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.01  │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.001 │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.001 │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.001 │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.001 │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.001 │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.001 │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.001 │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.001 │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [64]       │           0.001 │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.1   │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.1   │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.1   │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.1   │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.1   │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.1   │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.1   │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.1   │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.1   │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.01  │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.01  │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.01  │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.01  │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.01  │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.01  │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.01  │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.01  │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.01  │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.001 │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.001 │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.001 │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.001 │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.001 │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.001 │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.001 │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.001 │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [160, 100] │           0.001 │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.1   │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.1   │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.1   │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.1   │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.1   │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.1   │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.1   │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.1   │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.1   │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.01  │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.01  │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.01  │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.01  │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.01  │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.01  │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.01  │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.01  │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.01  │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.001 │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.001 │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.001 │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.001 │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.001 │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.001 │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.001 │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.001 │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 160] │           0.001 │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.1   │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.1   │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.1   │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.1   │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.1   │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.1   │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.1   │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.1   │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.1   │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.01  │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.01  │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.01  │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.01  │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.01  │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.01  │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.01  │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.01  │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.01  │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.001 │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.001 │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.001 │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.001 │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.001 │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.001 │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.001 │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.001 │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 100] │           0.001 │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.1   │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.1   │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.1   │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.1   │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.1   │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.1   │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.1   │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.1   │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.1   │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.01  │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.01  │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.01  │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.01  │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.01  │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.01  │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.01  │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.01  │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.01  │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.001 │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.001 │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.001 │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.001 │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.001 │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.001 │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.001 │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.001 │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [100, 60]  │           0.001 │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.1   │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.1   │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.1   │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.1   │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.1   │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.1   │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.1   │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.1   │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.1   │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.01  │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.01  │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.01  │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.01  │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.01  │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.01  │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.01  │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.01  │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.01  │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.001 │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.001 │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.001 │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.001 │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.001 │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.001 │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.001 │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.001 │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ relu         │ [60, 60]   │           0.001 │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.1   │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.1   │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.1   │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.1   │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.1   │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.1   │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.1   │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.1   │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.1   │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.01  │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.01  │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.01  │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.01  │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.01  │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.01  │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.01  │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.01  │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.01  │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.001 │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.001 │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.001 │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.001 │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ tanh         │ [256]      │           0.001 │           10 │              50 │                0 │
# ...
# │ sigmoid      │ [100, 100] │           0.1   │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.1   │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.1   │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.1   │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.1   │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.1   │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.1   │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.1   │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.01  │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.01  │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.01  │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.01  │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.01  │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.01  │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.01  │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.01  │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.01  │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.001 │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.001 │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.001 │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.001 │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.001 │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.001 │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.001 │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.001 │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 100] │           0.001 │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.1   │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.1   │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.1   │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.1   │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.1   │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.1   │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.1   │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.1   │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.1   │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.01  │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.01  │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.01  │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.01  │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.01  │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.01  │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.01  │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.01  │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.01  │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.001 │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.001 │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.001 │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.001 │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.001 │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.001 │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.001 │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.001 │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [100, 60]  │           0.001 │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.1   │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.1   │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.1   │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.1   │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.1   │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.1   │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.1   │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.1   │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.1   │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.01  │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.01  │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.01  │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.01  │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.01  │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.01  │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.01  │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.01  │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.01  │            1 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.001 │          100 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.001 │          100 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.001 │          100 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.001 │           10 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.001 │           10 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.001 │           10 │              10 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.001 │            1 │             100 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.001 │            1 │              50 │                0 │
# ├──────────────┼────────────┼─────────────────┼──────────────┼─────────────────┼──────────────────┤
# │ sigmoid      │ [60, 60]   │           0.001 │            1 │              10 │                0 │
# ╘══════════════╧════════════╧═════════════════╧══════════════╧═════════════════╧══════════════════╛

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import time
from sklearn.metrics import confusion_matrix

# Disable eager execution
tf.compat.v1.disable_eager_execution()

# Load MNIST dataset
mnist, info = tfds.load('mnist', with_info=True, as_supervised=True)

# Variations to test
activations = ['relu', 'tanh', 'sigmoid']
hidden_layer_sizes_single_layer = [256, 128, 64]
learning_rates = [0.1 , 0.01, 0.001]
batch_sizes = [100, 10, 1]
epochs_list = [100, 50, 10]
# hidden_layer_sizes_double_layer = [(160,100), (100,160), (100,100), (100,60), (60,60)]

# Function to define activation
def activation_function(x, activation):
    if activation == 'relu':
        return tf.nn.relu(x)
    elif activation == 'tanh':
        return tf.nn.tanh(x)
    elif activation == 'sigmoid':
        return tf.nn.sigmoid(x)
    else:
        return x  # Default case (no activation)

# Prepare the dataset
def preprocess(image, label):
    image = tf.reshape(image, [784])
    image = tf.cast(image, tf.float32) / 255.0
    label = tf.one_hot(label, 10)
    return image, label

# Function to build and train the model
def train_and_evaluate(activation, hidden_layers, learning_rate, batch_size, epochs):
    start_time = time.time()  # Start timer

    # Prepare data
    train_data = mnist['train'].map(preprocess).shuffle(60000).batch(batch_size)
    test_data = mnist['test'].map(preprocess).batch(batch_size)

    # Create iterator
    iterator = tf.compat.v1.data.make_initializable_iterator(train_data)
    next_element = iterator.get_next()

    # Placeholders
    X = tf.compat.v1.placeholder(tf.float32, [None, 784])
    Y = tf.compat.v1.placeholder(tf.float32, [None, 10])

    # Initialize weights and biases
    weights = {}
    biases = {}
    prev_size = 784

    # Hidden layers
    layer = X
    for i, size in enumerate(hidden_layers):
        weights[f'h{i+1}'] = tf.Variable(tf.random.normal([prev_size, size]))
        biases[f'b{i+1}'] = tf.Variable(tf.random.normal([size]))
        layer = activation_function(tf.add(tf.matmul(layer, weights[f'h{i+1}']), biases[f'b{i+1}']), activation)
        prev_size = size

    # Output layer
    weights['out'] = tf.Variable(tf.random.normal([prev_size, 10]))
    biases['out'] = tf.Variable(tf.random.normal([10]))
    logits = tf.add(tf.matmul(layer, weights['out']), biases['out'])

    # Loss and optimizer
    loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=Y))
    optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate)
    train_op = optimizer.minimize(loss_op)

    # Accuracy calculation
    correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(Y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

    # Initialize session
    init = tf.compat.v1.global_variables_initializer()
    loss_history = []
    accuracy_history = []

    with tf.compat.v1.Session() as sess:
        sess.run(init)
        sess.run(iterator.initializer)

        for epoch in range(epochs):
            try:
                while True:
                    batch_x, batch_y = sess.run(next_element)
                    _, loss, acc = sess.run([train_op, loss_op, accuracy], feed_dict={X: batch_x, Y: batch_y})
                    loss_history.append(loss)
                    accuracy_history.append(acc)
            except tf.errors.OutOfRangeError:
                sess.run(iterator.initializer)

        print(f"Completed: Activation={activation}, Layers={hidden_layers}, LR={learning_rate}, Batch={batch_size}, Epochs={epochs}")

        # Evaluate on test set
        test_iterator = tf.compat.v1.data.make_initializable_iterator(test_data)
        next_test_element = test_iterator.get_next()
        sess.run(test_iterator.initializer)
        test_acc = 0
        test_count = 0
        y_true, y_pred = [], []

        while True:
            try:
                test_images, test_labels = sess.run(next_test_element)
                acc, preds = sess.run([accuracy, tf.argmax(logits, 1)], feed_dict={X: test_images, Y: test_labels})
                y_true.extend(np.argmax(test_labels, axis=1))
                y_pred.extend(preds)
                test_acc += acc
                test_count += 1
            except tf.errors.OutOfRangeError:
                break

        test_acc /= test_count

        # Compute confusion matrix
        cm = confusion_matrix(y_true, y_pred)

        # Execution time
        execution_time = time.time() - start_time

        return loss_history, accuracy_history, test_acc, cm, execution_time

# Store results
results_single_layer = []
results_double_layer = []

# Run experiments for single-layer networks
for activation in activations:
    for hidden_size in hidden_layer_sizes_single_layer:
        for lr in learning_rates:
            for batch in batch_sizes:
                for epochs in epochs_list:
                    loss_hist, acc_hist, test_acc, cm, exec_time = train_and_evaluate(
                        activation, [hidden_size], lr, batch, epochs
                    )
                    results_single_layer.append([activation, 1, lr, batch, epochs, loss_hist[-1], acc_hist[-1], test_acc, cm, exec_time])

# # Run experiments for double-layer networks
# for activation in activations:
#     for hidden_sizes in hidden_layer_sizes_double_layer:
#         for lr in learning_rates:
#             for batch in batch_sizes:
#                 for epochs in epochs_list:
#                     loss_hist, acc_hist, test_acc, cm, exec_time = train_and_evaluate(
#                         activation, list(hidden_sizes), lr, batch, epochs
#                     )
#                     results_double_layer.append([activation, 2, lr, batch, epochs, loss_hist[-1], acc_hist[-1], test_acc, cm, exec_time])

# Convert to DataFrame for display
columns = ["Activation", "No. of Layers", "Learning Rate", "Batch Size", "Epochs", "Final Loss", "Final Accuracy", "Test Accuracy", "Confusion Matrix", "Execution Time"]

df_single_layer = pd.DataFrame(results_single_layer, columns=columns)
# df_double_layer = pd.DataFrame(results_double_layer, columns=columns)

# Display results
print("\nSingle Layer Results:")
display(df_single_layer)

# print("\nDouble Layer Results:")
# display(df_double_layer)
# Out:
# WARNING:tensorflow:From C:\Users\harsh\AppData\Local\Temp\ipykernel_348\1487918570.py:11: The name tf.disable_eager_execution is deprecated. Please use tf.compat.v1.disable_eager_execution instead.
#
# WARNING:tensorflow:From C:\Users\harsh\AppData\Local\Temp\ipykernel_348\1487918570.py:51: The name tf.data.make_initializable_iterator is deprecated. Please use tf.compat.v1.data.make_initializable_iterator instead.
# WARNING:tensorflow:From C:\Users\harsh\AppData\Local\Temp\ipykernel_348\1487918570.py:51: The name tf.data.make_initializable_iterator is deprecated. Please use tf.compat.v1.data.make_initializable_iterator instead.
# WARNING:tensorflow:From C:\Users\harsh\AppData\Local\Temp\ipykernel_348\1487918570.py:78: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From C:\Users\harsh\AppData\Local\Temp\ipykernel_348\1487918570.py:78: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# Completed: Activation=relu, Layers=[256], LR=0.1, Batch=100, Epochs=100
# Completed: Activation=relu, Layers=[256], LR=0.1, Batch=100, Epochs=50
# Completed: Activation=relu, Layers=[256], LR=0.1, Batch=100, Epochs=10
# Completed: Activation=relu, Layers=[256], LR=0.1, Batch=10, Epochs=100
# Completed: Activation=relu, Layers=[256], LR=0.1, Batch=10, Epochs=50
# Completed: Activation=relu, Layers=[256], LR=0.1, Batch=10, Epochs=10
# Completed: Activation=relu, Layers=[256], LR=0.1, Batch=1, Epochs=100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 145
#     143             for batch in batch_sizes:
#     144                 for epochs in epochs_list:
# --> 145                     loss_hist, acc_hist, test_acc, cm, exec_time = train_and_evaluate(
#     146                         activation, [hidden_size], lr, batch, epochs
#     147                     )
#     148                     results_single_layer.append([activation, 1, lr, batch, epochs, loss_hist[-1], acc_hist[-1], test_acc, cm, exec_time])
#     150 # # Run experiments for double-layer networks
#     151 # for activation in activations:
#     152 #     for hidden_sizes in hidden_layer_sizes_double_layer:
#    (...)
#     160
#     161 # Convert to DataFrame for display
#
# Cell In[1], line 98, in train_and_evaluate(activation, hidden_layers, learning_rate, batch_size, epochs)
#      96 while True:
#      97     batch_x, batch_y = sess.run(next_element)
# ---> 98     _, loss, acc = sess.run([train_op, loss_op, accuracy], feed_dict={X: batch_x, Y: batch_y})
#      99     loss_history.append(loss)
#     100     accuracy_history.append(acc)
#
# File c:\Users\harsh\.conda\envs\Projects\Lib\site-packages\tensorflow\python\client\session.py:977, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     974 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     976 try:
# --> 977   result = self._run(None, fetches, feed_dict, options_ptr,
#     978                      run_metadata_ptr)
#     979   if run_metadata:
#     980     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File c:\Users\harsh\.conda\envs\Projects\Lib\site-packages\tensorflow\python\client\session.py:1220, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1217 # We only want to really perform the run if fetches or targets are provided,
#    1218 # or if the call is a partial run that specifies feeds.
#    1219 if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1220   results = self._do_run(handle, final_targets, final_fetches,
#    1221                          feed_dict_tensor, options, run_metadata)
#    1222 else:
#    1223   results = []
#
# File c:\Users\harsh\.conda\envs\Projects\Lib\site-packages\tensorflow\python\client\session.py:1400, in BaseSession._do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1397   return self._call_tf_sessionprun(handle, feed_dict, fetch_list)
#    1399 if handle is None:
# -> 1400   return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1401                        run_metadata)
#    1402 else:
#    1403   return self._do_call(_prun_fn, handle, feeds, fetches)
#
# File c:\Users\harsh\.conda\envs\Projects\Lib\site-packages\tensorflow\python\client\session.py:1407, in BaseSession._do_call(self, fn, *args)
#    1405 def _do_call(self, fn, *args):
#    1406   try:
# -> 1407     return fn(*args)
#    1408   except errors.OpError as e:
#    1409     message = compat.as_text(e.message)
#
# File c:\Users\harsh\.conda\envs\Projects\Lib\site-packages\tensorflow\python\client\session.py:1390, in BaseSession._do_run.<locals>._run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1387 def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1388   # Ensure any changes to the graph are reflected in the runtime.
#    1389   self._extend_graph()
# -> 1390   return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1391                                   target_list, run_metadata)
#
# File c:\Users\harsh\.conda\envs\Projects\Lib\site-packages\tensorflow\python\client\session.py:1483, in BaseSession._call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1481 def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1482                         run_metadata):
# -> 1483   return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1484                                           fetch_list, target_list,
#    1485                                           run_metadata)
#
# KeyboardInterrupt:
